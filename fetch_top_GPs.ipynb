# %%
import scanpy as sc
import numpy as np

# Define datasets and cell type keys
datasets = ["forebrain", "pancreas", "gastrulation_erythroid", "dentategyrus_lamanno_P5"]
cell_type_keys = ["Clusters", "clusters", "celltype", "clusters"]

# Loop through datasets and process each
for dataset, cell_type_key in zip(datasets, cell_type_keys):
    adata = sc.read_h5ad(f"benchmark/imVelo/{dataset}/imVelo_{dataset}.h5ad")
    
    # Get the gene program activations from adata.obsm["z"]
    z = adata.obsm["z"]
    
    # Get the cell type labels
    cell_types = adata.obs[cell_type_key]
    
    # Get gene program names from adata.uns["terms"]
    gene_program_names = np.array(adata.uns["terms"])
    
    # For each cell type, compute the mean activation of each gene program
    unique_cell_types = cell_types.unique()
    
    for cell_type in unique_cell_types:
        # Subset data for the current cell type
        cell_type_mask = (cell_types == cell_type)
        z_cell_type = z[cell_type_mask, :]
        
        # Calculate the mean activation across cells for each gene program
        mean_activation = np.mean(z_cell_type, axis=0)
        
        # Find top 5 most activated (positive) and inactivated (negative) gene programs
        top_5_activated_idx = np.argsort(mean_activation)[-5:][::-1]  # Top 5 positive
        top_5_inactivated_idx = np.argsort(mean_activation)[:5]  # Top 5 negative
        
        # Print results for this cell type
        print(f"Top 5 activated gene programs for cell type: {cell_type} in dataset: {dataset}")
        for idx in top_5_activated_idx:
            print(f"{gene_program_names[idx]}: {mean_activation[idx]}")
        
        print(f"Top 5 inactivated gene programs for cell type: {cell_type} in dataset: {dataset}")
        for idx in top_5_inactivated_idx:
            print(f"{gene_program_names[idx]}: {mean_activation[idx]}")
        
        print("-" * 50)
# Out:
# Top 5 activated gene programs for cell type: Neuroblast 2 in dataset: forebrain
# PREFOLDIN_MEDIATED_TRANSFER_OF: 16.43832520212993
# PLATELET_ACTIVATION_SIGNALING_: 10.233322860725433
# HEMOSTASIS: 9.225308384761274
# PYRAMIDAL_CELLS: 8.447613077470098
# 3_UTR_MEDIATED_TRANSLATIONAL_R: 5.8996798446379515
# Top 5 inactivated gene programs for cell type: Neuroblast 2 in dataset: forebrain
# RESPONSE_TO_ELEVATED_PLATELET_: -29.640441971131597
# LOSS_OF_NLP_FROM_MITOTIC_CENTR: -8.113931739665418
# CARDIOMYOCYTES: -6.831082119999162
# AXON_GUIDANCE: -6.097901012524065
# ACTIVATION_OF_THE_MRNA_UPON_BI: -5.934456652905568
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Radial Glia 2 in dataset: forebrain
# MUSCLE_CONTRACTION: 8.715580810983496
# TRAF6_MEDIATED_INDUCTION_OF_NF: 6.246776203434151
# APOPTOTIC_EXECUTION_PHASE: 6.046907224748508
# DESTABILIZATION_OF_MRNA_BY_AUF: 5.756696156349527
# CIRCADIAN_REPRESSION_OF_EXPRES: 5.667605136352849
# Top 5 inactivated gene programs for cell type: Radial Glia 2 in dataset: forebrain
# RESPONSE_TO_ELEVATED_PLATELET_: -11.956004079565945
# MESANGIAL_CELLS: -10.323478400707245
# ASTROCYTES: -10.064232190150813
# MYD88_MAL_CASCADE_INITIATED_ON: -6.6999791163996045
# CARDIOMYOCYTES: -6.465034991861826
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Radial Glia 1 in dataset: forebrain
# BERGMANN_GLIA: 8.902370083459559
# APOPTOTIC_EXECUTION_PHASE: 7.748764525122821
# DESTABILIZATION_OF_MRNA_BY_AUF: 7.7356984462330045
# CIRCADIAN_REPRESSION_OF_EXPRES: 7.6924671349040965
# TRAF6_MEDIATED_INDUCTION_OF_NF: 7.500036887306581
# Top 5 inactivated gene programs for cell type: Radial Glia 1 in dataset: forebrain
# MESANGIAL_CELLS: -17.040791111196427
# RESPONSE_TO_ELEVATED_PLATELET_: -15.186960031641997
# ASTROCYTES: -14.819212483849755
# PROTEIN_FOLDING: -8.865083327267897
# MYD88_MAL_CASCADE_INITIATED_ON: -8.233351557012547
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Neuron in dataset: forebrain
# MAST_CELLS: 25.410099997449276
# NEURONS: 12.21185789179446
# 3_UTR_MEDIATED_TRANSLATIONAL_R: 8.222453651143544
# IMMATURE_NEURONS: 7.584892468665963
# RECRUITMENT_OF_MITOTIC_CENTROS: 7.509985180043462
# Top 5 inactivated gene programs for cell type: Neuron in dataset: forebrain
# FORMATION_OF_TUBULIN_FOLDING_I: -11.285367019140898
# LOSS_OF_NLP_FROM_MITOTIC_CENTR: -11.224048916973285
# SRP_DEPENDENT_COTRANSLATIONAL_: -8.968825432791638
# MITOTIC_G2_G2_M_PHASES: -7.062779551121726
# RESPONSE_TO_ELEVATED_PLATELET_: -6.813385924296592
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Immature Neuron 2 in dataset: forebrain
# MAST_CELLS: 19.16510645940961
# PREFOLDIN_MEDIATED_TRANSFER_OF: 13.250311887803882
# NEURONS: 12.435703049961923
# PHOTORECEPTOR_CELLS: 8.834083407013505
# CELL_CYCLE_MITOTIC: 7.880393185242704
# Top 5 inactivated gene programs for cell type: Immature Neuron 2 in dataset: forebrain
# LOSS_OF_NLP_FROM_MITOTIC_CENTR: -18.24004575941298
# RESPONSE_TO_ELEVATED_PLATELET_: -13.550953825805413
# FORMATION_OF_TUBULIN_FOLDING_I: -11.830636073532418
# MITOTIC_G2_G2_M_PHASES: -11.214173760433747
# CARDIOMYOCYTES: -8.498149986620303
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Immature Neuron 1 in dataset: forebrain
# PREFOLDIN_MEDIATED_TRANSFER_OF: 16.880719679576863
# MAST_CELLS: 9.471384952505057
# PHOTORECEPTOR_CELLS: 8.870044850478598
# NEURONS: 8.65069402148813
# PYRAMIDAL_CELLS: 6.986826431510772
# Top 5 inactivated gene programs for cell type: Immature Neuron 1 in dataset: forebrain
# RESPONSE_TO_ELEVATED_PLATELET_: -19.81372555394681
# LOSS_OF_NLP_FROM_MITOTIC_CENTR: -13.770263869068465
# MITOTIC_G2_G2_M_PHASES: -8.75767350265547
# FORMATION_OF_TUBULIN_FOLDING_I: -8.65104785432733
# CARDIOMYOCYTES: -7.993398215653917
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Neuroblast 1 in dataset: forebrain
# PREFOLDIN_MEDIATED_TRANSFER_OF: 6.651781959736601
# 3_UTR_MEDIATED_TRANSLATIONAL_R: 6.610281558746987
# TRANSLATION: 6.519618917018809
# PLATELET_ACTIVATION_SIGNALING_: 6.31710343665265
# HEMOSTASIS: 5.834786118345058
# Top 5 inactivated gene programs for cell type: Neuroblast 1 in dataset: forebrain
# RESPONSE_TO_ELEVATED_PLATELET_: -18.472012834346042
# ACTIVATION_OF_THE_MRNA_UPON_BI: -6.926247677904494
# CARDIOMYOCYTES: -6.797035668758636
# SRP_DEPENDENT_COTRANSLATIONAL_: -6.233757724153235
# GLUCOSE_METABOLISM: -5.568168929282655
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Pre-endocrine in dataset: pancreas
# ENTEROENDOCRINE_CELLS: 24.05047532254704
# ALPHA_CELLS: 12.308462189258757
# IMMUNE_SYSTEM: 11.367763461293402
# SIGNALLING_BY_NGF: 9.021617527749088
# MAMMARY_EPITHELIAL_CELLS: 8.635972664162919
# Top 5 inactivated gene programs for cell type: Pre-endocrine in dataset: pancreas
# ERYTHROID-LIKE_AND_ERYTHROID_P: -13.998121253541997
# METABOLISM_OF_PROTEINS: -11.415401461962107
# HEMOSTASIS: -11.106556086926847
# METABOLISM_OF_MRNA: -10.312469978590268
# TRANSLATION: -9.380984005090353
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Ductal in dataset: pancreas
# LUMINAL_EPITHELIAL_CELLS: 11.412285233168623
# OSTEOBLASTS: 10.480695567797365
# PEPTIDE_CHAIN_ELONGATION: 10.246805435705394
# METABOLISM_OF_RNA: 9.861556676797992
# IMMUNE_SYSTEM: 7.819880191936243
# Top 5 inactivated gene programs for cell type: Ductal in dataset: pancreas
# OSTEOCLASTS: -14.245554288922438
# METABOLISM_OF_PROTEINS: -10.841408116328143
# NONSENSE_MEDIATED_DECAY_ENHANC: -10.368454203334958
# INFLUENZA_VIRAL_RNA_TRANSCRIPT: -10.1693359004358
# MÜLLER_CELLS: -9.638084970186892
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Alpha in dataset: pancreas
# GLUCAGON_SIGNALING_IN_METABOLI: 27.339625246156775
# GPCR_DOWNSTREAM_SIGNALING: 21.226924459552567
# G_ALPHA_I_SIGNALLING_EVENTS: 17.02006374723946
# EPITHELIAL_CELLS: 16.361445101500795
# REGULATION_OF_INSULIN_SECRETIO: 14.698652186719487
# Top 5 inactivated gene programs for cell type: Alpha in dataset: pancreas
# PEPTIDE_LIGAND_BINDING_RECEPTO: -19.02093422288954
# CLASS_A1_RHODOPSIN_LIKE_RECEPT: -18.70812814157619
# REGULATION_OF_INSULIN_SECRETIO_1: -12.927545426541208
# ERYTHROID-LIKE_AND_ERYTHROID_P: -12.10025363454204
# TCA_CYCLE_AND_RESPIRATORY_ELEC: -11.514172552033422
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Ngn3 high EP in dataset: pancreas
# PLATELET_ACTIVATION_SIGNALING_: 11.85237364090306
# FIBROBLASTS: 11.210050818704742
# IMMUNE_SYSTEM: 9.475618628326606
# MICROFOLD_CELLS: 9.29910647683426
# MAMMARY_EPITHELIAL_CELLS: 8.607585995368126
# Top 5 inactivated gene programs for cell type: Ngn3 high EP in dataset: pancreas
# DEVELOPMENTAL_BIOLOGY: -12.993057032240515
# METABOLISM_OF_PROTEINS: -11.756678290084887
# EXTRACELLULAR_MATRIX_ORGANIZAT: -11.25059683894814
# ERYTHROID-LIKE_AND_ERYTHROID_P: -10.964261254046194
# TRANSLATION: -10.845467640232075
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Delta in dataset: pancreas
# GPCR_DOWNSTREAM_SIGNALING: 27.670912647247313
# GPCR_LIGAND_BINDING: 17.36339580672128
# PROXIMAL_TUBULE_CELLS: 11.429617282322475
# IMMUNE_SYSTEM: 11.14295369556972
# SIGNALLING_BY_NGF: 8.603802973883493
# Top 5 inactivated gene programs for cell type: Delta in dataset: pancreas
# PEPTIDE_LIGAND_BINDING_RECEPTO: -44.416700908115935
# CLASS_A1_RHODOPSIN_LIKE_RECEPT: -35.02494309289115
# DELTA_CELLS: -27.990102222987584
# GLUCAGON_SIGNALING_IN_METABOLI: -22.519741930280414
# SIGNALING_BY_GPCR: -20.05720751455852
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Beta in dataset: pancreas
# REGULATION_OF_GENE_EXPRESSION_: 16.927998202718957
# NEURONS: 16.688695655861483
# GPCR_DOWNSTREAM_SIGNALING: 14.354780360829407
# ENTEROENDOCRINE_CELLS: 12.313701452135838
# G_ALPHA_I_SIGNALLING_EVENTS: 11.268530356702465
# Top 5 inactivated gene programs for cell type: Beta in dataset: pancreas
# BETA_CELLS: -24.38500886873339
# PEPTIDE_LIGAND_BINDING_RECEPTO: -16.139105965643363
# CLASS_A1_RHODOPSIN_LIKE_RECEPT: -15.718537908721897
# TCA_CYCLE_AND_RESPIRATORY_ELEC: -13.266493006607805
# DELTA_CELLS: -13.058899759237738
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Ngn3 low EP in dataset: pancreas
# LUMINAL_EPITHELIAL_CELLS: 11.226396005572253
# OSTEOBLASTS: 11.099836455046676
# PEPTIDE_CHAIN_ELONGATION: 9.946573113667146
# METABOLISM_OF_RNA: 9.851184797650985
# IMMUNE_SYSTEM: 8.112133992537288
# Top 5 inactivated gene programs for cell type: Ngn3 low EP in dataset: pancreas
# OSTEOCLASTS: -14.943119954061872
# METABOLISM_OF_PROTEINS: -10.990348193481678
# NONSENSE_MEDIATED_DECAY_ENHANC: -10.28025772007367
# MÜLLER_CELLS: -10.087595151580928
# INFLUENZA_VIRAL_RNA_TRANSCRIPT: -10.058549688062595
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Epsilon in dataset: pancreas
# IMMUNE_SYSTEM: 11.317243670074033
# PROXIMAL_TUBULE_CELLS: 10.840219958987035
# SIGNALING_BY_GPCR: 9.284052311744489
# REGULATION_OF_GENE_EXPRESSION_: 9.195026920714849
# SIGNALLING_BY_NGF: 9.16418719291687
# Top 5 inactivated gene programs for cell type: Epsilon in dataset: pancreas
# PEPTIDE_LIGAND_BINDING_RECEPTO: -41.44912118643102
# G_ALPHA_Q_SIGNALLING_EVENTS: -39.330553545078764
# GASTRIN_CREB_SIGNALLING_PATHWA: -23.186568051996364
# DELTA_CELLS: -17.074577764726023
# ERYTHROID-LIKE_AND_ERYTHROID_P: -13.390084266662598
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Erythroid1 in dataset: gastrulation_erythroid
# IRON_UPTAKE_AND_TRANSPORT: 33.65994188287756
# ASPARAGINE_N_LINKED_GLYCOSYLAT: 30.144374485854264
# 3_UTR_MEDIATED_TRANSLATIONAL_R: 24.28407688455267
# PYRUVATE_METABOLISM_AND_CITRIC: 23.511965539429212
# POST_TRANSLATIONAL_PROTEIN_MOD: 21.491148985349216
# Top 5 inactivated gene programs for cell type: Erythroid1 in dataset: gastrulation_erythroid
# ERYTHROID-LIKE_AND_ERYTHROID_P: -116.99456916798601
# SIGNALING_BY_INSULIN_RECEPTOR: -23.55569703238351
# CHROMOSOME_MAINTENANCE: -21.205643894908192
# NONSENSE_MEDIATED_DECAY_ENHANC: -18.980916513191474
# ACTIVATION_OF_THE_MRNA_UPON_BI: -16.339371935351863
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Erythroid2 in dataset: gastrulation_erythroid
# IRON_UPTAKE_AND_TRANSPORT: 36.39989405860586
# ASPARAGINE_N_LINKED_GLYCOSYLAT: 27.948018488608117
# 3_UTR_MEDIATED_TRANSLATIONAL_R: 22.664065889090544
# PYRUVATE_METABOLISM_AND_CITRIC: 22.105685781053275
# POST_TRANSLATIONAL_PROTEIN_MOD: 19.88160963137288
# Top 5 inactivated gene programs for cell type: Erythroid2 in dataset: gastrulation_erythroid
# ERYTHROID-LIKE_AND_ERYTHROID_P: -212.1611016643934
# SIGNALING_BY_INSULIN_RECEPTOR: -25.243481253001317
# CHROMOSOME_MAINTENANCE: -19.642253837900714
# NONSENSE_MEDIATED_DECAY_ENHANC: -17.820833499372497
# ACTIVATION_OF_THE_MRNA_UPON_BI: -15.21460617160009
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Blood progenitors 1 in dataset: gastrulation_erythroid
# ASPARAGINE_N_LINKED_GLYCOSYLAT: 30.805621034958783
# IRON_UPTAKE_AND_TRANSPORT: 24.610485301298255
# 3_UTR_MEDIATED_TRANSLATIONAL_R: 24.555100553175983
# PYRUVATE_METABOLISM_AND_CITRIC: 22.466715812683105
# POST_TRANSLATIONAL_PROTEIN_MOD: 22.1374013003181
# Top 5 inactivated gene programs for cell type: Blood progenitors 1 in dataset: gastrulation_erythroid
# CHROMOSOME_MAINTENANCE: -21.680843914256375
# NONSENSE_MEDIATED_DECAY_ENHANC: -19.23212455300724
# SIGNALING_BY_INSULIN_RECEPTOR: -17.70209778056425
# ACTIVATION_OF_THE_MRNA_UPON_BI: -16.58590513117173
# PEPTIDE_CHAIN_ELONGATION: -16.34640183168299
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Erythroid3 in dataset: gastrulation_erythroid
# IRON_UPTAKE_AND_TRANSPORT: 36.23758424714554
# ASPARAGINE_N_LINKED_GLYCOSYLAT: 26.253938652748285
# 3_UTR_MEDIATED_TRANSLATIONAL_R: 21.399642234624817
# PYRUVATE_METABOLISM_AND_CITRIC: 20.69483309013899
# POST_TRANSLATIONAL_PROTEIN_MOD: 18.682551217633623
# Top 5 inactivated gene programs for cell type: Erythroid3 in dataset: gastrulation_erythroid
# ERYTHROID-LIKE_AND_ERYTHROID_P: -257.1592226250227
# SIGNALING_BY_INSULIN_RECEPTOR: -25.022275314774625
# CHROMOSOME_MAINTENANCE: -18.356327733328175
# NONSENSE_MEDIATED_DECAY_ENHANC: -16.87862880839858
# PEPTIDE_CHAIN_ELONGATION: -14.354892187340315
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Blood progenitors 2 in dataset: gastrulation_erythroid
# ASPARAGINE_N_LINKED_GLYCOSYLAT: 30.940589684706467
# IRON_UPTAKE_AND_TRANSPORT: 25.86770120033851
# 3_UTR_MEDIATED_TRANSLATIONAL_R: 24.681619106194912
# PYRUVATE_METABOLISM_AND_CITRIC: 22.789561259440887
# POST_TRANSLATIONAL_PROTEIN_MOD: 22.221787489377537
# Top 5 inactivated gene programs for cell type: Blood progenitors 2 in dataset: gastrulation_erythroid
# ERYTHROID-LIKE_AND_ERYTHROID_P: -22.90711926191281
# CHROMOSOME_MAINTENANCE: -21.779984241876846
# NONSENSE_MEDIATED_DECAY_ENHANC: -19.310969303815792
# SIGNALING_BY_INSULIN_RECEPTOR: -18.53754344353309
# ACTIVATION_OF_THE_MRNA_UPON_BI: -16.65403141119541
# --------------------------------------------------
# Top 5 activated gene programs for cell type: RadialGlia in dataset: dentategyrus_lamanno_P5
# MÜLLER_CELLS: 23.18611205977563
# METABOLISM_OF_PROTEINS: 10.840570790956773
# TCA_CYCLE_AND_RESPIRATORY_ELEC: 10.083764111828842
# MELANOCYTES: 8.694807946774674
# HEMOSTASIS: 7.235773328303549
# Top 5 inactivated gene programs for cell type: RadialGlia in dataset: dentategyrus_lamanno_P5
# ASTROCYTES: -21.625517020885532
# IMMUNE_SYSTEM: -8.289827384622434
# FIBROBLASTS: -7.749352007965277
# STROMAL_CELLS: -7.429324443427437
# GPCR_DOWNSTREAM_SIGNALING: -6.97970775794093
# --------------------------------------------------
# Top 5 activated gene programs for cell type: GlialProg in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_PROTEINS: 13.985619135429523
# TCA_CYCLE_AND_RESPIRATORY_ELEC: 10.068782151111064
# RESPONSE_TO_ELEVATED_PLATELET_: 8.814066945409483
# HEMOSTASIS: 8.760778321810296
# SRP_DEPENDENT_COTRANSLATIONAL_: 8.353345267611779
# Top 5 inactivated gene programs for cell type: GlialProg in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_MRNA: -13.880479259724998
# 3_UTR_MEDIATED_TRANSLATIONAL_R: -12.086019463334347
# TRANSLATION: -8.971858934756437
# OLIGODENDROCYTE_PROGENITOR_CEL: -7.365643800219144
# MAST_CELLS: -7.351356784258884
# --------------------------------------------------
# Top 5 activated gene programs for cell type: ImmGranule1 in dataset: dentategyrus_lamanno_P5
# RESPONSE_TO_ELEVATED_PLATELET_: 15.867126804805089
# METABOLISM_OF_PROTEINS: 15.565917004252944
# PLATELET_ACTIVATION_SIGNALING_: 13.18055652999114
# HEMOSTASIS: 12.05019155650018
# DEVELOPMENTAL_BIOLOGY: 9.622355715773294
# Top 5 inactivated gene programs for cell type: ImmGranule1 in dataset: dentategyrus_lamanno_P5
# TRANSLATION: -14.451177862839641
# MAST_CELLS: -7.144561452922898
# NEURONAL_SYSTEM: -6.555298865398514
# CELL_CELL_COMMUNICATION: -6.252547064833393
# RNA_POL_I_RNA_POL_III_AND_MITO: -6.0944906949042
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Granule in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_PROTEINS: 15.671305933088627
# RESPONSE_TO_ELEVATED_PLATELET_: 12.84472567630264
# IRON_UPTAKE_AND_TRANSPORT: 12.692375970336625
# PLATELET_ACTIVATION_SIGNALING_: 11.661917528453863
# HEMOSTASIS: 9.863222191356263
# Top 5 inactivated gene programs for cell type: Granule in dataset: dentategyrus_lamanno_P5
# MAST_CELLS: -10.080091402215778
# SIGNALING_BY_GPCR: -10.07048868177072
# INTERNEURONS: -8.246211967378292
# NEURONAL_SYSTEM: -7.948937455438218
# NEUROENDOCRINE_CELLS: -7.384005345825879
# --------------------------------------------------
# Top 5 activated gene programs for cell type: ImmAstro in dataset: dentategyrus_lamanno_P5
# MELANOCYTES: 19.100632338957933
# MÜLLER_CELLS: 17.568875479091762
# HEPARAN_SULFATE_HEPARIN_HS_GAG: 12.552427858463332
# ENTEROENDOCRINE_CELLS: 11.601885174671649
# BERGMANN_GLIA: 10.855890160025044
# Top 5 inactivated gene programs for cell type: ImmAstro in dataset: dentategyrus_lamanno_P5
# ASTROCYTES: -23.3979703350419
# TRANSMEMBRANE_TRANSPORT_OF_SMA: -10.080748954850188
# MAST_CELLS: -8.127858788932024
# IMMUNE_SYSTEM: -7.904476255457723
# METABOLISM_OF_AMINO_ACIDS_AND_: -7.821404140517415
# --------------------------------------------------
# Top 5 activated gene programs for cell type: ImmGranule2 in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_PROTEINS: 16.787437530405988
# HEMOSTASIS: 12.308614894085819
# DEVELOPMENTAL_BIOLOGY: 10.140349977065528
# RESPONSE_TO_ELEVATED_PLATELET_: 9.939584888590506
# TCA_CYCLE_AND_RESPIRATORY_ELEC: 8.340633122143482
# Top 5 inactivated gene programs for cell type: ImmGranule2 in dataset: dentategyrus_lamanno_P5
# TRANSLATION: -9.732539490511074
# MAST_CELLS: -9.604199933850753
# CELL_CELL_COMMUNICATION: -7.5502662596697405
# NEURONAL_SYSTEM: -6.715917210925052
# NEURONS: -6.634949618661907
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Nbl1 in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_PROTEINS: 13.177647413583747
# DCC_MEDIATED_ATTRACTIVE_SIGNAL: 10.747849572434204
# HEMOSTASIS: 9.223023907544743
# TCA_CYCLE_AND_RESPIRATORY_ELEC: 9.131575008987877
# INFLUENZA_LIFE_CYCLE: 8.817364419059915
# Top 5 inactivated gene programs for cell type: Nbl1 in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_MRNA: -10.443659029932464
# FIBROBLASTS: -8.54768646819682
# 3_UTR_MEDIATED_TRANSLATIONAL_R: -8.004337155869239
# TRANSCRIPTION: -7.918196084630138
# TRANSLATION: -7.5815581988056
# --------------------------------------------------
# Top 5 activated gene programs for cell type: Nbl2 in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_PROTEINS: 13.62188805985318
# NEUROBLASTS: 12.280295571060039
# RESPONSE_TO_ELEVATED_PLATELET_: 12.231775813730838
# PLATELET_ACTIVATION_SIGNALING_: 11.887963090624128
# HEMOSTASIS: 9.901153543221044
# Top 5 inactivated gene programs for cell type: Nbl2 in dataset: dentategyrus_lamanno_P5
# TRANSLATION: -14.618181541810895
# RNA_POL_I_RNA_POL_III_AND_MITO: -12.296294510917452
# FIBROBLASTS: -9.18562734458796
# TRANSCRIPTION: -7.469842261418783
# ENTEROCYTES: -7.000100200384137
# --------------------------------------------------
# Top 5 activated gene programs for cell type: CA in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_PROTEINS: 15.865474656776145
# RESPONSE_TO_ELEVATED_PLATELET_: 15.619976476386741
# PLATELET_ACTIVATION_SIGNALING_: 13.350705561814484
# HEMOSTASIS: 11.04210478288156
# DEVELOPMENTAL_BIOLOGY: 9.225622596564117
# Top 5 inactivated gene programs for cell type: CA in dataset: dentategyrus_lamanno_P5
# TRANSLATION: -11.92472549058773
# MAST_CELLS: -7.572674636487608
# NEURONAL_SYSTEM: -6.581102088645652
# CELL_CELL_COMMUNICATION: -6.37113129651105
# NEURONS: -5.625236822499169
# --------------------------------------------------
# Top 5 activated gene programs for cell type: CA2-3-4 in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_PROTEINS: 16.311010336631288
# ERYTHROID-LIKE_AND_ERYTHROID_P: 14.541090445906136
# GLOMUS_CELLS: 10.168075513726816
# HEMOSTASIS: 9.47273947445539
# IRON_UPTAKE_AND_TRANSPORT: 9.211653739519729
# Top 5 inactivated gene programs for cell type: CA2-3-4 in dataset: dentategyrus_lamanno_P5
# NEURONS: -13.017510007664079
# MAST_CELLS: -11.208702940967202
# ADAPTIVE_IMMUNE_SYSTEM: -10.913865461627987
# SIGNALING_BY_GPCR: -9.663574444184457
# NEURONAL_SYSTEM: -8.693775235336412
# --------------------------------------------------
# Top 5 activated gene programs for cell type: CA1-Sub in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_PROTEINS: 16.66894182344762
# ERYTHROID-LIKE_AND_ERYTHROID_P: 11.201670736219825
# RESPONSE_TO_ELEVATED_PLATELET_: 11.082462773671965
# HEMOSTASIS: 10.222819421349502
# DEVELOPMENTAL_BIOLOGY: 9.473877894006124
# Top 5 inactivated gene programs for cell type: CA1-Sub in dataset: dentategyrus_lamanno_P5
# G_ALPHA_Q_SIGNALLING_EVENTS: -12.908187839606914
# MAST_CELLS: -11.836331055803997
# NEURONS: -11.299801267065654
# ADAPTIVE_IMMUNE_SYSTEM: -9.08699364836623
# NEURONAL_SYSTEM: -8.920963016370449
# --------------------------------------------------
# Top 5 activated gene programs for cell type: nIPC in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_PROTEINS: 12.46774099347429
# TCA_CYCLE_AND_RESPIRATORY_ELEC: 9.148871973137034
# HEMOSTASIS: 9.03412214076726
# METABOLISM_OF_RNA: 7.86052448504439
# MRNA_PROCESSING: 7.304749219853664
# Top 5 inactivated gene programs for cell type: nIPC in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_MRNA: -9.22850556124514
# TRANSCRIPTION: -7.695341240102363
# FIBROBLASTS: -7.456740359916228
# 3_UTR_MEDIATED_TRANSLATIONAL_R: -7.2290785099380965
# IMMUNE_SYSTEM: -7.106811787957979
# --------------------------------------------------
# Top 5 activated gene programs for cell type: OPC in dataset: dentategyrus_lamanno_P5
# METABOLISM_OF_PROTEINS: 12.864719680231861
# SRP_DEPENDENT_COTRANSLATIONAL_: 9.752587104200298
# PEPTIDE_CHAIN_ELONGATION: 9.607713126473957
# TCA_CYCLE_AND_RESPIRATORY_ELEC: 9.31532904225537
# HEMOSTASIS: 8.74309779334272
# Top 5 inactivated gene programs for cell type: OPC in dataset: dentategyrus_lamanno_P5
# OLIGODENDROCYTE_PROGENITOR_CEL: -13.101521822249788
# METABOLISM_OF_MRNA: -11.631977582589174
# MAST_CELLS: -10.909954961548504
# 3_UTR_MEDIATED_TRANSLATIONAL_R: -9.395318621498907
# VOLTAGE_GATED_POTASSIUM_CHANNE: -8.591728741350847
# --------------------------------------------------
# Top 5 activated gene programs for cell type: RadialGlia2 in dataset: dentategyrus_lamanno_P5
# MÜLLER_CELLS: 24.321167591639927
# MELANOCYTES: 10.895995834895542
# METABOLISM_OF_PROTEINS: 10.468485014779228
# TCA_CYCLE_AND_RESPIRATORY_ELEC: 10.001538848876953
# BERGMANN_GLIA: 6.970986557006836
# Top 5 inactivated gene programs for cell type: RadialGlia2 in dataset: dentategyrus_lamanno_P5
# ASTROCYTES: -21.968491799490792
# IMMUNE_SYSTEM: -8.389753695896694
# STROMAL_CELLS: -7.3027744974408835
# GPCR_DOWNSTREAM_SIGNALING: -7.283866500854492
# FIBROBLASTS: -7.091966199874878
# --------------------------------------------------
