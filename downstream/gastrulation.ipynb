# %%
import numpy as np
import matplotlib.pyplot as plt
import scanpy as sc
from plotting import plot_phase_plane
import os

# %%
gastrulation_path = "/mnt/data2/home/leonardo/git/imVelo/gastrulation_erythroid_test_1_2499/gastrulation_erythroid/K11/adata/adata_K11_dt_ve.h5ad"
gastrulation = sc.read_h5ad(gastrulation_path)

# %%
gene_name = "Rpl18a"
dataset = "gastrulation_erythroid"
base_path = f"phase_plane_plots/{dataset}"
os.makedirs(base_path, exist_ok=True)
gene_path = f"{base_path}/{gene_name}.png"
save_plot=True

# %%
plot_phase_plane(gastrulation, gene_name, u_scale=0.1, s_scale=0.1, dataset=dataset, K=11, cell_type_key="celltype", save_path=gene_path, save_plot=save_plot)

# %%
pancreas_path = "/mnt/data2/home/leonardo/git/imVelo/pancreas_test_2499/pancreas/K11/adata/adata_K11_dt_ve.h5ad"
pancreas = sc.read_h5ad(pancreas_path)

# %%
gene_name = "Tecr"
dataset = "pancreas"
cell_type_key = "clusters"
base_path = f"phase_plane_plots/{dataset}"
os.makedirs(base_path, exist_ok=True)
gene_path = f"{base_path}/{gene_name}.png"
save_plot=True

# %%
plot_phase_plane(pancreas, gene_name, u_scale=0.1, s_scale=0.1, dataset=dataset, K=11, save_path=gene_path, save_plot=save_plot)
# Out:
# /mnt/data2/home/leonardo/git/imVelo/plotting.py:91: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_type_index = np.where(unique_cell_types == cell_types_filtered[i])[0][0]
# /mnt/data2/home/leonardo/git/imVelo/plotting.py:92: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   arrow_color = celltype_to_color[cell_types_filtered[i]]  # Use the color corresponding to the cell type
# Plot saved to phase_plane_plots/pancreas/Tecr.png

# %%
dentategyrus_path = "/mnt/data2/home/leonardo/git/imVelo/dentategyrus_lamanno_P5_test_1/dentategyrus_lamanno_P5/K31/adata/adata_K31_dt_ve.h5ad"
dentategyrus = sc.read_h5ad(dentategyrus_path)

# %%
gene_name = "Syne1"
dataset = "dentategyrus"
cell_type_key = "clusters"
base_path = f"phase_plane_plots/{dataset}"
os.makedirs(base_path, exist_ok=True)
gene_path = f"{base_path}/{gene_name}.png"
save_plot=True

# %%
plot_phase_plane(dentategyrus, gene_name, u_scale=0.1, s_scale=0.1, dataset=dataset, K=11, save_path=gene_path, save_plot=save_plot)
# Out:
# Plot saved to phase_plane_plots/dentategyrus/Syne1.png

# %%
forebrain_path = "/mnt/data2/home/leonardo/git/imVelo/benchmark/imVelo/forebrain/forebrain/K11/adata/adata_K11_dt_ve.h5ad"
forebrain = sc.read_h5ad(forebrain_path)

# %%
gene_name = "Gnas"
dataset = "forebrain"
cell_type_key = "Clusters"
base_path = f"phase_plane_plots/{dataset}"
os.makedirs(base_path, exist_ok=True)
gene_path = f"{base_path}/{gene_name}.png"
save_plot=True

# %%
plot_phase_plane(forebrain, gene_name, u_scale=0.1, s_scale=0.1, cell_type_key=cell_type_key, dataset=dataset, K=11, save_path=gene_path, save_plot=save_plot)
# Out:
# Plot saved to phase_plane_plots/forebrain/Gnas.png
