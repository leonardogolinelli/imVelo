# %%
import numpy as np
import pandas as pd
import scvelo as scv
import scanpy as sc
import matplotlib.pyplot as plt
from scvelo_adapted_utils import load_files
from scvelo_adapted_metrics import compute_scvelo_metrics

# %%
adata = scv.datasets.gastrulation_erythroid()
# Out:
# 100%|██████████| 463M/463M [00:16<00:00, 29.8MB/s]

# %%
sc.pl.umap(adata, color=adata.var_names[0], color_map="gnuplot")

# %%
adata = sc.read_h5ad("pancreas/scvelo_pancreas.h5ad")

# %%
scv.tl.latent_time(adata)
adata

# %%
import matplotlib.pyplot as plt

# %%
sc.pl.umap(adata, color="latent_time", color_map="gnuplot")
plt.savefig("pancreas/scvelo_metrics/confidence/latent_time.png")

# %%
scv.pl.velocity_embedding_stream(adata, color="latent_time", color_map="gnuplot")
plt.savefig("pancreas/scvelo_metrics/confidence/latent_time_stream.png")
plt.

# %%
adata = sc.read_h5ad("../../outputs/final_anndatas/pancreas/scvelo.h5ad")
#scv.tl.velocity_graph(adata)
scv.pl.velocity_embedding_stream(adata, color="clusters")

# %%
"""adata = sc.read_h5ad("scvelo.h5ad")
adata_sub = adata[:, adata.var["velocity_genes"]].copy()
miVelo_velocity = adata_mivelo[:,adata_sub.var_names].layers["velocity"]
scVelo_velocity = adata_sub.layers["velocity"]
corr = scv.utils.vcorrcoef(miVelo_velocity, scVelo_velocity, mode='pearsons', axis=- 1)"""
