# %%
import numpy as np
import scipy.stats as st

import cellrank as cr
import scanpy as sc

cr.settings.verbosity = 2
sc.settings.set_figure_params(
    frameon=False,
    dpi=100,
)

# %%
import warnings

warnings.simplefilter("ignore", category=UserWarning)

# %%
adata = cr.datasets.pancreas(kind="preprocessed-kernel")

vk = cr.kernels.VelocityKernel.from_adata(adata, key="T_fwd")
vk
# Out:
# 100%|██████████| 234M/234M [00:07<00:00, 34.1MB/s]
# VelocityKernel[n=2531, model='deterministic', similarity='correlation', softmax_scale=4.013]

# %%
sc.pl.embedding(adata, basis="umap", color="clusters")

# %%
g = cr.estimators.GPCCA(vk)
print(g)
# Out:
# GPCCA[kernel=VelocityKernel[n=2531], initial_states=None, terminal_states=None]

# %%
g.fit(cluster_key="clusters", n_states=[4, 12])
g.plot_macrostates(which="all", discrete=True, legend_loc="right", s=100)
# Out:
# WARNING: Unable to import `petsc4py` or `slepc4py`. Using `method='brandts'`
# WARNING: For `method='brandts'`, dense matrix is required. Densifying
# Computing Schur decomposition
# When computing macrostates, choose a number of states NOT in `[5, 10]`
# Adding `adata.uns['eigendecomposition_fwd']`
#        `.schur_vectors`
#        `.schur_matrix`
#        `.eigendecomposition`
#     Finish (0:00:03)
# Calculating minChi criterion in interval `[4, 12]`
# Computing `4` macrostates
# Adding `.macrostates`
#        `.macrostates_memberships`
#        `.coarse_T`
#        `.coarse_initial_distribution
#        `.coarse_stationary_distribution`
#        `.schur_vectors`
#        `.schur_matrix`
#        `.eigendecomposition`
#     Finish (0:00:00)

# %%
g.predict_initial_states()
g.plot_macrostates(which="initial", legend_loc="right", s=100)
# Out:
# Adding `adata.obs['init_states_fwd']`
#        `adata.obs['init_states_fwd_probs']`
#        `.initial_states`
#        `.initial_states_probabilities`
#        `.initial_states_memberships
#     Finish`

# %%
g
# Out:
# GPCCA[kernel=VelocityKernel[n=2531], initial_states=['Ngn3 low EP'], terminal_states=None]

# %%
np.nan_to_num

# %%
root_cell_index = g.initial_states_probabilities.idxmax()
root_cell_index

#print(f"Root cell: {root_cell}")
# Out:
# 'GGAATAAGTAGCTAAA-1-3'

# %%
adata[root_cell_index].
# Out:
#                        day proliferation  G2M_score   S_score phase  \
# index
# GGAATAAGTAGCTAAA-1-3  15.5   Non-Cycling   -0.15973 -0.135054    G1
#
#                      clusters_coarse     clusters clusters_fine louvain_Alpha  \
# index
# GGAATAAGTAGCTAAA-1-3     Ngn3 low EP  Ngn3 low EP   Ngn3 low EP           NaN
#
#                      louvain_Beta  palantir_pseudotime  \
# index
# GGAATAAGTAGCTAAA-1-3          NaN             0.001702
#
#                       initial_size_unspliced  initial_size_spliced  \
# index
# GGAATAAGTAGCTAAA-1-3                   917.0                6866.0
#
#                       initial_size     n_counts macrostates_fwd  \
# index
# GGAATAAGTAGCTAAA-1-3        6866.0  4644.394531     Ngn3 low EP
#
#                      init_states_fwd  init_states_fwd_probs
# index
# GGAATAAGTAGCTAAA-1-3     Ngn3 low EP                    1.0

# %%
root_cell = adata.obs_names[g.initial_states.idxmax()]
print(f"Root cell: {root_cell}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 root_cell = adata.obs_names[g.initial_states.idxmax()]
#       2 print(f"Root cell: {root_cell}")
#
# File ~/miniconda3/envs/DeepTrajectory/lib/python3.11/site-packages/pandas/core/indexes/base.py:5416, in Index.__getitem__(self, key)
#    5407         if len(key) == 0 and len(key) != len(self):
#    5408             warnings.warn(
#    5409                 "Using a boolean indexer with length 0 on an Index with "
#    5410                 "length greater than 0 is deprecated and will raise in a "
#    (...)
#    5413                 stacklevel=find_stack_level(),
#    5414             )
# -> 5416 result = getitem(key)
#    5417 # Because we ruled out integer above, we always get an arraylike here
#    5418 if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
